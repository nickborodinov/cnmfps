# %%
# %load_ext autoreload
# %autoreload 2

# %%
from cnmf import spectroscopic_map

# %%
file=r"C:\Users\ni1\Documents\NanoIR-PS\cnmfps\data\IRData_16x16.csv"
folder=r"C:\Users\ni1\Documents\NanoIR-PS\cnmfps\data\maps"

# %%
workflow=spectroscopic_map(ir_file=file,
                   folder=folder)
workflow.load_data(hi_res_spatial_x=256,
            hi_res_spatial_y=256,
            hs_resolution_x=16,
            hs_resolution_y=16,
            limit_range=[0,3000],
            data_format='new',
            sg=False,
            limit_maps=False)

# %%
#workflow.define_endmembers(method='nfindr',components=2)

# %%
workflow.do_nmf(N_NMF_components=2)
workflow.plot_maps()
workflow.plot_components()
